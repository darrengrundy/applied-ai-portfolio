# %% [markdown]
# # Setup
#
# Import Semantic Kernel SDK from pypi.org

# %%
# Note: if using a virtual environment, do not run this cell
# %pip install -U semantic-kernel
from semantic_kernel import __version__

__version__
# Out:
# Requirement already satisfied: semantic-kernel in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (1.44.0)
# Collecting semantic-kernel
#   Downloading semantic_kernel-1.44.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: azure-ai-projects<2.5,>=1.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (1.0.0)
# Requirement already satisfied: azure-ai-agents>=1.2.0b3 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (1.2.0b6)
# Requirement already satisfied: aiohttp~=3.8 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (3.14.1)
# Requirement already satisfied: cloudevents<3,>=1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (1.13.0)
# Requirement already satisfied: pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.14,>=2.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (2.13.4)
# Requirement already satisfied: pydantic-settings~=2.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (2.14.2)
# Requirement already satisfied: defusedxml~=0.7 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (0.7.1)
# Requirement already satisfied: azure-identity>=1.13 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (1.25.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (2.5.0)
# Requirement already satisfied: openai>=2.0.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (2.44.0)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (0.19.5)
# Requirement already satisfied: websockets<16,>=13 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (15.0.1)
# Requirement already satisfied: aiortc>=1.9.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (1.15.0)
# Requirement already satisfied: opentelemetry-api~=1.24 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (1.38.0)
# Requirement already satisfied: prance<26.7.20,>=23.6.21 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (25.4.8.0)
# Requirement already satisfied: pybars4~=0.9 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (0.9.13)
# Requirement already satisfied: jinja2~=3.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (3.1.6)
# Requirement already satisfied: nest-asyncio~=1.6 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (1.6.0)
# Requirement already satisfied: scipy>=1.15.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (1.18.0)
# Requirement already satisfied: typing-extensions>=4.13 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from semantic-kernel) (4.16.0)
# Collecting mcp<2.0,>=1.26.0 (from semantic-kernel)
#   Using cached mcp-1.29.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aiohttp~=3.8->semantic-kernel) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aiohttp~=3.8->semantic-kernel) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aiohttp~=3.8->semantic-kernel) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aiohttp~=3.8->semantic-kernel) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.24.2)
# Requirement already satisfied: isodate>=0.6.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from azure-ai-projects<2.5,>=1.0->semantic-kernel) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from azure-ai-projects<2.5,>=1.0->semantic-kernel) (1.41.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from azure-ai-projects<2.5,>=1.0->semantic-kernel) (12.30.0)
# Requirement already satisfied: deprecation<3.0,>=2.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from cloudevents<3,>=1->semantic-kernel) (2.1.0)
# Requirement already satisfied: packaging in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from deprecation<3.0,>=2.0->cloudevents<3,>=1->semantic-kernel) (26.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from jinja2~=3.1->semantic-kernel) (3.0.3)
# Requirement already satisfied: anyio>=4.5 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from mcp<2.0,>=1.26.0->semantic-kernel) (4.14.1)
# Collecting httpx-sse>=0.4 (from mcp<2.0,>=1.26.0->semantic-kernel)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.27.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from mcp<2.0,>=1.26.0->semantic-kernel) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from mcp<2.0,>=1.26.0->semantic-kernel) (4.26.0)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0,>=1.26.0->semantic-kernel) (2.13.0)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from mcp<2.0,>=1.26.0->semantic-kernel) (0.0.32)
# Requirement already satisfied: pywin32>=311 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from mcp<2.0,>=1.26.0->semantic-kernel) (312)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from mcp<2.0,>=1.26.0->semantic-kernel) (3.4.6)
# Requirement already satisfied: starlette>=0.48.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from mcp<2.0,>=1.26.0->semantic-kernel) (0.49.3)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from mcp<2.0,>=1.26.0->semantic-kernel) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from mcp<2.0,>=1.26.0->semantic-kernel) (0.49.0)
# Requirement already satisfied: certifi in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from httpx<1.0.0,>=0.27.1->mcp<2.0,>=1.26.0->semantic-kernel) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from httpx<1.0.0,>=0.27.1->mcp<2.0,>=1.26.0->semantic-kernel) (1.0.9)
# Requirement already satisfied: idna in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from httpx<1.0.0,>=0.27.1->mcp<2.0,>=1.26.0->semantic-kernel) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.1->mcp<2.0,>=1.26.0->semantic-kernel) (0.16.0)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.3.4)
# Requirement already satisfied: more-itertools in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (11.1.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.2)
# Requirement already satisfied: parse in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (1.22.1)
# Requirement already satisfied: werkzeug<3.1.2 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (3.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.26.0->semantic-kernel) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.26.0->semantic-kernel) (0.36.2)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.26.0->semantic-kernel) (2026.5.1)
# Requirement already satisfied: PyYAML>=5.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (6.0.3)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (0.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (2.34.2)
# Requirement already satisfied: rfc3339-validator in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel) (1.12.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from opentelemetry-api~=1.24->semantic-kernel) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel) (4.1.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from opentelemetry-sdk~=1.24->semantic-kernel) (0.59b0)
# Requirement already satisfied: chardet>=5.2 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from prance<26.7.20,>=23.6.21->semantic-kernel) (7.4.3)
# Requirement already satisfied: ruamel.yaml>=0.18.10 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from prance<26.7.20,>=23.6.21->semantic-kernel) (0.19.1)
# Requirement already satisfied: PyMeta3>=0.5.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from pybars4~=0.9->semantic-kernel) (0.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.14,>=2.0->semantic-kernel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.14,>=2.0->semantic-kernel) (2.46.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from pydantic-settings~=2.0->semantic-kernel) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (2.7.0)
# Requirement already satisfied: aioice<1.0.0,>=0.10.2 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (0.10.2)
# Requirement already satisfied: av<18.0.0,>=14.0.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (17.1.0)
# Requirement already satisfied: cryptography>=44.0.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (49.0.0)
# Requirement already satisfied: google-crc32c>=1.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (1.8.0)
# Requirement already satisfied: pyee>=13.0.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (13.0.1)
# Requirement already satisfied: pylibsrtp>=0.10.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (1.0.0)
# Requirement already satisfied: pyopenssl>=25.0.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (26.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aioice<1.0.0,>=0.10.2->aiortc>=1.9.0->semantic-kernel) (2.8.0)
# Requirement already satisfied: ifaddr>=0.2.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from aioice<1.0.0,>=0.10.2->aiortc>=1.9.0->semantic-kernel) (0.2.0)
# Requirement already satisfied: msal>=1.35.1 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from azure-identity>=1.13->semantic-kernel) (1.37.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from azure-identity>=1.13->semantic-kernel) (1.3.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from cryptography>=44.0.0->aiortc>=1.9.0->semantic-kernel) (2.0.0)
# Requirement already satisfied: pycparser in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=44.0.0->aiortc>=1.9.0->semantic-kernel) (3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from openai>=2.0.0->semantic-kernel) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from openai>=2.0.0->semantic-kernel) (0.15.0)
# Requirement already satisfied: sniffio in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from openai>=2.0.0->semantic-kernel) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from openai>=2.0.0->semantic-kernel) (4.68.3)
# Requirement already satisfied: colorama in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from tqdm>4->openai>=2.0.0->semantic-kernel) (0.4.6)
# Requirement already satisfied: click>=7.0 in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from uvicorn>=0.31.1->mcp<2.0,>=1.26.0->semantic-kernel) (8.4.2)
# Requirement already satisfied: six in c:\Users\grund\OneDrive\_1DAX\AI-Engineering-TDAI\.venv\Lib\site-packages (from rfc3339-validator->openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel) (1.17.0)
# Downloading semantic_kernel-1.44.1-py3-none-any.whl (937 kB)
#    ---------------------------------------- 0.0/937.8 kB ? eta -:--:--
#    ---------------------------------------- 937.8/937.8 kB 12.4 MB/s  0:00:00
# Using cached mcp-1.29.0-py3-none-any.whl (223 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Installing collected packages: httpx-sse, mcp, semantic-kernel
#
#   Attempting uninstall: mcp
#
#     Found existing installation: mcp 2.0.0
#
#     Uninstalling mcp-2.0.0:
#
#       Successfully uninstalled mcp-2.0.0
#
#    ------------- -------------------------- 1/3 [mcp]
#   Attempting uninstall: semantic-kernel
#    ------------- -------------------------- 1/3 [mcp]
#     Found existing installation: semantic-kernel 1.44.0
#    ------------- -------------------------- 1/3 [mcp]
#    -------------------------- ------------- 2/3 [semantic-kernel]
#     Uninstalling semantic-kernel-1.44.0:
#    -------------------------- ------------- 2/3 [semantic-kernel]
#       Successfully uninstalled semantic-kernel-1.44.0
#    -------------------------- ------------- 2/3 [semantic-kernel]
#    -------------------------- ------------- 2/3 [semantic-kernel]
#    -------------------------- ------------- 2/3 [semantic-kernel]
#    -------------------------- ------------- 2/3 [semantic-kernel]
#    -------------------------- ------------- 2/3 [semantic-kernel]
#    -------------------------- ------------- 2/3 [semantic-kernel]
#    -------------------------- ------------- 2/3 [semantic-kernel]
#    -------------------------- ------------- 2/3 [semantic-kernel]
#    ---------------------------------------- 3/3 [semantic-kernel]
#
# Successfully installed httpx-sse-0.4.3 mcp-1.29.0 semantic-kernel-1.44.1
# Note: you may need to restart the kernel to use updated packages.
# '1.44.1'

# %% [markdown]
# Initial configuration for the notebook to run properly.

# %%
# Make sure paths are correct for the imports

import os
import sys

notebook_dir = os.path.abspath("")
parent_dir = os.path.dirname(notebook_dir)
grandparent_dir = os.path.dirname(parent_dir)

sys.path.append(grandparent_dir)

# %% [markdown]
# ### Configuring the Kernel
#
# Let's get started with the necessary configuration to run Semantic Kernel. For Notebooks, we require a `.env` file with the proper settings for the model you use. Create a new file named `.env` and place it in this directory. Copy the contents of the `.env.example` file from this directory and paste it into the `.env` file that you just created.
#
# **NOTE: Please make sure to include `GLOBAL_LLM_SERVICE` set to either OpenAI, AzureOpenAI, or HuggingFace in your .env file. If this setting is not included, the Service will default to AzureOpenAI.**
#
# #### Option 1: using OpenAI
#
# Add your [OpenAI Key](https://openai.com/product/) key to your `.env` file (org Id only if you have multiple orgs):
#
# ```
# GLOBAL_LLM_SERVICE="OpenAI"
# OPENAI_API_KEY="sk-..."
# OPENAI_ORG_ID=""
# OPENAI_CHAT_MODEL_ID=""
# OPENAI_TEXT_MODEL_ID=""
# OPENAI_EMBEDDING_MODEL_ID=""
# ```
# The names should match the names used in the `.env` file, as shown above.
#
# #### Option 2: using Azure OpenAI
#
# Add your [Azure Open AI Service key](https://learn.microsoft.com/azure/cognitive-services/openai/quickstart?pivots=programming-language-studio) settings to the `.env` file in the same folder:
#
# ```
# GLOBAL_LLM_SERVICE="AzureOpenAI"
# AZURE_OPENAI_API_KEY="..."
# AZURE_OPENAI_ENDPOINT="https://..."
# AZURE_OPENAI_CHAT_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_TEXT_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_API_VERSION="..."
# ```
# The names should match the names used in the `.env` file, as shown above.
#
# For more advanced configuration, please follow the steps outlined in the [setup guide](./CONFIGURING_THE_KERNEL.md).

# %% [markdown]
# Let's define our kernel for this example.

# %%
from semantic_kernel import Kernel

kernel = Kernel()

# %% [markdown]
# We will load our settings and get the LLM service to use for the notebook.

# %%
from services import Service

from samples.service_settings import ServiceSettings

service_settings = ServiceSettings()

# Select a service to use for this notebook (available services: OpenAI, AzureOpenAI, HuggingFace)
selectedService = (
    Service.AzureOpenAI
    if service_settings.global_llm_service is None
    else Service(service_settings.global_llm_service.lower())
)
print(f"Using service type: {selectedService}")
# Out:
# Using service type: Service.AzureOpenAI

# %% [markdown]
# We now configure our Chat Completion service on the kernel.

# %%
# Remove all services so that this cell can be re-run without restarting the kernel
kernel.remove_all_services()

service_id = None
if selectedService == Service.OpenAI:
    from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion

    service_id = "default"
    kernel.add_service(
        OpenAIChatCompletion(
            service_id=service_id,
        ),
    )
elif selectedService == Service.AzureOpenAI:
    from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

    service_id = "default"
    kernel.add_service(
        AzureChatCompletion(service_id=service_id),
    )

# %% [markdown]
# # Run a Semantic Function
#
# **Step 3**: Load a Plugin and run a semantic function:

# %%
plugin = kernel.add_plugin(parent_directory=notebook_dir, plugin_name="FunPlugin")

# %%
from semantic_kernel.functions import KernelArguments

joke_function = plugin["Joke"]

joke = await kernel.invoke(
    joke_function,
    KernelArguments(input="time travel to dinosaur age", style="super silly"),
)
print(joke)
# Out:
# Why did the time traveler bring a ladder to the dinosaur age?
#
# Because they heard the T-Rex was a little short on “dino-sore” jokes and wanted to help him reach new heights in comedy!
#
# But when they got there, the T-Rex just looked at them and said, “I can’t reach the punchline, but I can sure reach you!”
#
# And that’s how the first-ever stand-up comedy show for dinosaurs ended with a “T-Rex-ceptional” roar of laughter!
